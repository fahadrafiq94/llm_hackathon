# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# C:\Users\Mian\AppData\Local\Temp\ipykernel_22088\4237154184.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
report = pd.read_csv("data/forecast_report.csv", sep=";")
print(report.head(5))
# Out:
#   business_unit product_family  forecast_previous_month_production_2024  \
# 0            AL         Prozil                                      103
# 1            AL          Focix                                      789
# 2            AL         Zentra                                       42
# 3            AL          Optix                                      957
# 4            AL         Mentix                                      221
#
#    forecast_current_month_production_2024  \
# 0                                     104
# 1                                     631
# 2                                      34
# 3                                     766
# 4                                     177
#
#    forecast_current_month_marketing_2024  possible_supply_for_2024
# 0                                    120                       100
# 1                                    770                      1000
# 2                                     35                        50
# 3                                    800                       500
# 4                                    200                       500

# %%
print(report.describe())
# Out:
#        forecast_previous_month_production_2024  \
# count                                22.000000
# mean                                471.272727
# std                                 345.730033
# min                                  42.000000
# 25%                                 172.250000
# 50%                                 388.000000
# 75%                                 769.500000
# max                                1130.000000
#
#        forecast_current_month_production_2024  \
# count                               22.000000
# mean                               420.090909
# std                                336.937031
# min                                 34.000000
# 25%                                172.500000
# 50%                                309.000000
# 75%                                622.500000
# max                               1251.000000
#
#        forecast_current_month_marketing_2024  possible_supply_for_2024
# count                              22.000000                 22.000000
# mean                              439.318182                595.454545
# std                               366.678448                438.859206
# min                                10.000000                 50.000000
# 25%                               112.500000                500.000000
# 50%                               345.000000                500.000000
# 75%                               792.500000                875.000000
# max                              1100.000000               2000.000000

# %%
report.head()
# Out:
#   business_unit product_family  forecast_previous_month_production_2024  \
# 0            AL         Prozil                                      103
# 1            AL          Focix                                      789
# 2            AL         Zentra                                       42
# 3            AL          Optix                                      957
# 4            AL         Mentix                                      221
#
#    forecast_current_month_production_2024  \
# 0                                     104
# 1                                     631
# 2                                      34
# 3                                     766
# 4                                     177
#
#    forecast_current_month_marketing_2024  possible_supply_for_2024
# 0                                    120                       100
# 1                                    770                      1000
# 2                                     35                        50
# 3                                    800                       500
# 4                                    200                       500

# %%
report["business_unit"].unique()
# Out:
# array(['AL', 'WT', 'QU', 'WZ', 'OZT'], dtype=object)

# %%
# Drop non-numeric columns
numeric_df = report.drop(columns=['business_unit', 'product_family'])

# Correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
